# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1 Creando un dataFrame usando arrays

# %% [markdown]
# 1.1 Opcion 1

# %%
# creando un array
data = np.array([[1,4], [2,5], [3,4]])

# %%
# creando un dataframe
df = pd.DataFrame(data, index=['row1','row2','row3'],
            columns=['col1','col2'])

# %%
# mostrando el dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     4

# %% [markdown]
# 1.2 Opcion 2

# %%
# creando un array en forma de lista
data = [[1,4],[2,5],[3,4]]

# %%
# creando un dataframe
df = pd.DataFrame(data, index=['row1','row2','row3'],
                columns=['col1','col2'])

# %%
#  mostrando el dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     4

# %% [markdown]
# 2 Creando un dataframe usando diccionarios

# %%
# listas usadas para el ejemplo
states = ['California','Texas','Florida','New York']
population = [39613493, 29730311, 21944577, 19299981]

# %%
#   Almacenando listas en un diccionario
dic_states = {'States':states, 'Population':population}

# %%
# creando el dataframe
df_population = pd.DataFrame(dic_states)

# %%
# mostrando el dataframe
df_population
# Out:
#        States  Population
# 0  California    39613493
# 1       Texas    29730311
# 2     Florida    21944577
# 3    New York    19299981

# %% [markdown]
# 3 Creando un dataframe con archivos csv

# %%
# leyendo el archivo csv
df_exams = pd.read_csv('StudentsPerformance.csv')

# %%
#  mostrando el dataframe
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# 4 Mostrando un Dataframe

# %%
import pandas as pd

# %%
# leyendo el archivo CSV
df_exams = pd.read_csv('StudentsPerformance.csv')

# %%
#
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# mostrar primeras 5 filas del dataframe
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# mostrar ultimas 5 filas del dataframe
df_exams.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
# mostrar ultimas n filas del dataframe
df_exams.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
# para imprimir todo el DataFrame
df_exams.to_string()

# %%
# accediendo al atributo shape
df_exams.shape
# Out:
# (1000, 8)

# %%
# mostrar "n" filas
pd.set_option('display.max_rows', 10)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# selecciona la columna como index
dataFrame = pd.read_csv('src/users.csv')
dataFrame
# Out:
#      Unnamed: 0              nombre  edad  genero            pais  \
# 0             0    Mr Jerome Thomas    73    male   United States
# 1             1       Mr Gary Berry    70    male  United Kingdom
# 2             2     Mr Noham Dubois    40    male          France
# 3             3   Mrs Naja Johansen    63  female         Denmark
# 4             4  Mr Damien Marchand    61    male          France
# ..          ...                 ...   ...     ...             ...
# 195         195       Mr Raul Bravo    46    male           Spain
# 196         196   Miss Maeva Fortin    40  female          Canada
# 197         197   Mr Gabriel Berger    40    male          France
# 198         198  Mrs Ülkü Tanrıkulu    37  female          Turkey
# 199         199     Mr Raff Valkema    60    male     Netherlands
#
#                            email
# 0      jerome.thomas@example.com
# 1         gary.berry@example.com
# 2       noham.dubois@example.com
# 3      naja.johansen@example.com
# ...

# %% [markdown]
# 5 Atributos

# %%
df_exams.shape
# Out:
# (1000, 8)

# %%
df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# 6 Metodos

# %%
# mostrando las 5 primeras filas
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# mostrando informacion del dataframe
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# obteniendo valores estadisticos del dataframe
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# 7 Funciones

# %%
# obtener el tamaño del dataframe
len(df_exams)
# Out:
# 1000

# %%
# obtener el maximo index
max(df_exams.index)
# Out:
# 999

# %%
# obtener el minimo index
min(df_exams.index)
# Out:
# 0

# %%
# obtener el tipo de dato
type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %%
# redondear valores del dataframe
round(df_exams, 2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# 8 Seleccionar 1 columna

# %% [markdown]
# 8.1 Syntax 1

# %%
# seleccionar una columna con [] (forma preferida de seleccionar una columna)
df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# revisar el tipo de data de una columna
type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
# series: atributos y metodos
df_exams['gender'].index
df_exams['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %% [markdown]
# 8.2 Syntax 2

# %%
# seleccionar una columna con .
df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# seleccionar una columna con . (errores que encontraras)
df_exams.math score
# Out:
#   File "/tmp/ipykernel_6415/1977785841.py", line 2
#     df_exams.math score
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# 9 Seleccionar dos o mas columnas

# %%
import pandas as pd

# %%
df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# seleccionar 2 columnas usando [[]]
df_exams[['gender','math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
# revisar el tipo de data de la seleccion
type(df_exams[['gender','math score']])
# Out:
# pandas.core.frame.DataFrame

# %%
# seleccionar 2 o mas columnas usando [[]]
df_exams[['gender','math score','reading score', 'writing score']]
# Out:
#      gender  math score  reading score  writing score
# 0    female          72             72             74
# 1    female          69             90             88
# 2    female          90             95             93
# 3      male          47             57             44
# 4      male          76             78             75
# ..      ...         ...            ...            ...
# 995  female          88             99             95
# 996    male          62             55             55
# 997  female          59             71             65
# 998  female          68             78             77
# 999  female          77             86             86
#
# [1000 rows x 4 columns]

# %%
# no podemos  seleccionar 2 o mas colimnas usando el "."
df_exams.'gender', 'math score'
# Out:
#   File "/tmp/ipykernel_5313/1665390467.py", line 2
#     df_exams.'gender', 'math score'
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# 10 Agregar una nueva columna

# %% [markdown]
# 10.1 Agregar una nueva columna con un valor

# %%
import pandas as pd

# %%
df_exams = pd.read_csv('src/StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# agregar una nueva columna al dataframe
df_exams['language score'] = 70
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
import numpy as np

# %%
# crear un array de 1000 elementos
language_score = np.arange(0, 1000)

# %%
# tamaño del array
len(language_score)
# Out:
# 1000

# %%
# agregar una nueva columna al dataframe con un array
df_exams['language score'] = language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# crear numeros enteros aleatorios entre 1 y 100
int_language_score = np.random.randint(1, 100, size=1000)

# %%
# el minimo valor es inclusivo y el maximo es exclusivo
min(int_language_score)
max(int_language_score)
# Out:
# 99

# %%
# agregar una nueva columna al dataframe con un array
df_exams['language score'] = int_language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# renombrar la columna
df_exams.rename(
    columns={'language score':'score'}
)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score
# ...

# %%
# crear numeros decimales aleatorios entre 1 y 100
np.random.uniform(1, 100, size=1000)
# Out:
# array([14.0707253 , 97.92482548, 52.00963987, 66.7961101 , 29.3642596 ,
#        89.1655032 , 20.78564897, 14.40194418, 86.01462027, 48.94274446,
#        86.94331757, 99.3660497 , 64.00939779, 11.80264036, 28.44461115,
#        78.66236149,  9.88803472, 14.04619588, 56.21132787, 45.62075758,
#        58.80806127, 67.97713606, 73.31141876, 72.17184142,  7.3129341 ,
#        35.45791332, 91.79001739, 96.28311365, 30.58707611,  7.86035638,
#        61.81343449, 97.20878101, 93.92151914, 37.98814593, 41.85265581,
#        91.72868551, 21.9387521 , 98.12960007, 82.64223351, 71.10476434,
#         4.77729618, 91.40030596, 83.4421237 , 46.441122  , 34.99990459,
#         7.19180918, 11.40393009, 98.51979084, 69.33688674, 90.70418298,
#        42.14272742, 46.94541263, 25.48999087, 98.88256058, 83.38951896,
#        27.0286654 , 99.8003317 , 29.45980433, 67.77886523, 88.14491724,
#        55.07572816, 73.21580601,  2.31926308,  1.6448267 , 42.87015433,
# ...

# %% [markdown]
# 11 Operaciones

# %% [markdown]
# 11.1 Operaciones en columnas

# %%
import pandas as pd

# %%
df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# selecciona una columna y calcula la suma total
df_exams['math score'].sum()
# Out:
# 66089

# %%
# contar, promedio, desv. estandar, maximo y minimo 
df_exams['math score'].count()
df_exams['math score'].mean()
df_exams['math score'].std()
df_exams['math score'].max()
df_exams['math score'].min()
# Out:
# 0

# %%
# calcula mas rapido con .describe()
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# 11.2 Operaciones en una fila

# %%
# calcular la suma en una fila
df_exams['math score'] + df_exams['reading score'] + df_exams['writing score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
# calcular el score promedio y asignar los resultados en una nueva columna
df_exams['average'] = (df_exams['math score'] + df_exams['reading score'] + df_exams['writing score'])/3

# %%
# mostrar el dataframe
df_exams.round(2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  average
# ...

# %% [markdown]
# 12 Value Counts (metodo para contar cada categoria por columna)

# %%
# contar los  elementos en la columna "gender"

# funcion len
len(df_exams['gender'])

# metodo .count()
df_exams['gender'].count()
# Out:
# 1000

# %%
# contar elementos "gender" por categoria
df_exams['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
# obtener la frecuencia relativa / o porcentaje (dividir todos los valores entre la suma)
df_exams['gender'].value_counts(normalize=True)
# Out:
# female    0.518
# male      0.482
# Name: gender, dtype: float64

# %%
# contar elementos de la columna "parental level of education" por categoria
df_exams['parental level of education'].value_counts(normalize=True)
# Out:
# some college          0.226
# associate's degree    0.222
# high school           0.196
# some high school      0.179
# bachelor's degree     0.118
# master's degree       0.059
# Name: parental level of education, dtype: float64

# %%
# obtener la frecuencia relativa y redondear a 2 decimales
df_exams['parental level of education'].value_counts(normalize=True).round(2)
# Out:
# some college          0.23
# associate's degree    0.22
# high school           0.20
# some high school      0.18
# bachelor's degree     0.12
# master's degree       0.06
# Name: parental level of education, dtype: float64

# %% [markdown]
# 13 Ordenar un Dataframe con sort_values()

# %%
df_exams.sort_values('math score')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 625    male        group D                some college      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# 962  female        group E          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# orden descendiente
df_exams.sort_values(['math score'], ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# orden descendiente por multiples columnas
df_exams.sort_values(['math score','reading score'], ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# orden descendiente por multiples columnas y actualizar dataframe
df_exams.sort_values(['math score','reading score'], ascending=False, 
                    inplace=True)

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# orden descendiente co una funcion key
df_exams.sort_values('race/ethnicity', ascending=True,
                        key=lambda col:col.str.lower())
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 741  female        group A          associate's degree  free/reduced
# 151    male        group A           bachelor's degree      standard
# 811    male        group A                 high school  free/reduced
# 112    male        group A          associate's degree      standard
# 25     male        group A             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 751    male        group E                some college      standard
# 915  female        group E                some college      standard
# 592    male        group E           bachelor's degree      standard
# 479    male        group E          associate's degree      standard
# 517  female        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Obtener el usuario mas joven del pais Canada

import pandas as pd

data = pd.read_csv('src/users.csv')

data[data['pais'] == 'Canada'].sort_values('edad').head(1)
# Out:
#      Unnamed: 0              nombre  edad genero    pais  \
# 184         184  Mr Philip Bélanger    24   male  Canada
#
#                            email
# 184  philip.belanger@example.com

# %%
# Obtener a los 5 usuarios mas viejos de Alemania

import pandas as pd

data = pd.read_csv('src/users.csv')

data[data['pais'] == 'Germany'].sort_values('edad', ascending=False).head(5)
# Out:
#      Unnamed: 0                  nombre  edad  genero     pais  \
# 79           79  Ms Hanne Aschenbrenner    64  female  Germany
# 5             5        Mr Harri Althoff    56    male  Germany
# 144         144        Ms Mareile Plate    51  female  Germany
# 56           56      Ms Marcella Brosch    38  female  Germany
# 7             7       Ms Britta Weinert    35  female  Germany
#
#                                email
# 79   hanne.aschenbrenner@example.com
# 5          harri.althoff@example.com
# 144        mareile.plate@example.com
# 56       marcella.brosch@example.com
# 7         britta.weinert@example.com

# %% [markdown]
# Busqueda por rangos

# %%
# obtener todos los usuarios entre las edades 40 y 50

import pandas as pd

data = pd.read_csv('src/users.csv')

#data[ (data['edad'] >= 40) & (data['edad'] <= 50) ]
data[ data['edad'].between(40, 50) ]
# Out:
#      Unnamed: 0                          nombre  edad  genero            pais  \
# 2             2                 Mr Noham Dubois    40    male          France
# 6             6                   Mr Noah Olsen    40    male         Denmark
# 8             8                Mr Jakob Russell    44    male         Ireland
# 23           23             Mrs Tilde Mortensen    42  female         Denmark
# 35           35                Ms Wenda Laurens    41  female     Netherlands
# 36           36                 Mr Anthony Wong    42    male          Canada
# 41           41                Miss Iida Ketola    46  female         Finland
# 42           42         Miss Ceylan Nalbantoğlu    48  female          Turkey
# 46           46                Mrs Phyllis West    46  female   United States
# 48           48                Miss مهدیس حیدری    46  female            Iran
# 51           51            Miss Victoire Giraud    50  female          France
# ...

# %% [markdown]
# Busqueda entre opciones

# %%
# Obtener el nombre de todos los usuarios mayores a 30 años de los paises Canada, Alemania y Francia

import pandas as pd

data = pd.read_csv('src/users.csv')

data[ (data['edad'] > 30) & (data['pais'] == 'Canada') | (data['pais'] == 'Germany') | (data['pais'] == 'France') ]

#countries = ['Canada','Germany','France']
#data [ (data['edad' > 30]) & (data['pais'].isin(countries)) ]
# Out:
#      Unnamed: 0                  nombre  edad  genero     pais  \
# 2             2         Mr Noham Dubois    40    male   France
# 4             4      Mr Damien Marchand    61    male   France
# 5             5        Mr Harri Althoff    56    male  Germany
# 7             7       Ms Britta Weinert    35  female  Germany
# 20           20    Mr Vincenzo Rauscher    25    male  Germany
# 21           21           Mr Louis Ross    60    male   Canada
# 29           29        Mr Ilyès Lemaire    75    male   France
# 36           36         Mr Anthony Wong    42    male   Canada
# 50           50          Mr Theo Miller    33    male   Canada
# 51           51    Miss Victoire Giraud    50  female   France
# 56           56      Ms Marcella Brosch    38  female  Germany
# 58           58      Miss Madison Ennis    49  female   Canada
# 79           79  Ms Hanne Aschenbrenner    64  female  Germany
# 85           85      Mrs Luisa Weißmann    32  female  Germany
# ...

# %% [markdown]
# 14  Setear max_filas (configuracion de opciones de Pandas)

# %%
import pandas as pd

# verificar las filas maximas por defecto de su Pandas
print(pd.options.display.max_rows)
# Out:
# 60

# %%
#  cambiar el número máximo de filas a visualizar con la misma declaración
pd.options.display.max_rows = 9999

# %% [markdown]
# 15 Serie Pandas

# %%
# Una Serie Pandas es como una columna en una tabla.

# Es una matriz unidimensional que contiene datos de cualquier tipo.

# %% [markdown]
# 15.1 Series con Listas

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a)

myvar
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
myvar = pd.Series(a, index = ["x", "y", "z"])

myvar
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
myvar['y']
# Out:
# 7

# %%
myvar_2 = pd.Series(a, index = ["x", "y", "z"], 
                 name='Numeros', dtype=str)

myvar_2
# Out:
# x    1
# y    7
# z    2
# Name: Numeros, dtype: object

# %% [markdown]
# 15.2 Series con clave/valor (diccionario)

# %%
import pandas as pd

calories = {
            "day1": 420,
            "day2": 380,
            "day3": 390
            }

myvar = pd.Series(calories)

myvar
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# 16 Limpieza de datos: celdas vacias

# %% [markdown]
# Valores nulos

# %%
# En Python es None
# Numpy o Pandas = NaN (not as number)

# %%
import numpy as np

np.nan
# Out:
# nan

# %%
pd.Series([1, 2, np.nan, np.nan, 5, 6, 7, np.nan, 8, 9])
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    NaN
# 4    5.0
# 5    6.0
# 6    7.0
# 7    NaN
# 8    8.0
# 9    9.0
# dtype: float64

# %%
# isnull - notnull

# %%
a = pd.Series([1, 2, np.nan, np.nan, 5, 6, 7, np.nan, 8, 9])

# %%
a.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9    False
# dtype: bool

# %%
a.notnull()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7    False
# 8     True
# 9     True
# dtype: bool

# %%
a[a.isnull()]
# Out:
# 2   NaN
# 3   NaN
# 7   NaN
# dtype: float64

# %%
a[a.notnull()]
# Out:
# 0    1.0
# 1    2.0
# 4    5.0
# 5    6.0
# 6    7.0
# 8    8.0
# 9    9.0
# dtype: float64

# %% [markdown]
# 16.1 Quitar filas

# %%
# Una forma de lidiar con las celdas vacías es eliminar las filas que contienen celdas vacías.

import pandas as pd

df = pd.read_csv('data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
new_df = df.dropna()

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 164 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  164 non-null    int64
#  1   Pulse     164 non-null    int64
#  2   Maxpulse  164 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.4 KB

# %% [markdown]
# 16.2 Reemplazar valores vacíos

# %%
# El fillna()método nos permite reemplazar las celdas vacías con un valor (130)

import pandas as pd

df = pd.read_csv('src/data.csv')

# %%
# inplace = True modifica el DataFrame original
df.fillna(130, inplace = True)

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
# Para reemplazar solo los valores vacíos de una columna

df["Calories"].fillna(130, inplace = True)

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
dataFrame = pd.read_csv('src/users.csv')
dataFrame[dataFrame.isnull()]
# Out:
#      Unnamed: 0 nombre  edad genero pais email
# 0           NaN    NaN   NaN    NaN  NaN   NaN
# 1           NaN    NaN   NaN    NaN  NaN   NaN
# 2           NaN    NaN   NaN    NaN  NaN   NaN
# 3           NaN    NaN   NaN    NaN  NaN   NaN
# 4           NaN    NaN   NaN    NaN  NaN   NaN
# ..          ...    ...   ...    ...  ...   ...
# 195         NaN    NaN   NaN    NaN  NaN   NaN
# 196         NaN    NaN   NaN    NaN  NaN   NaN
# 197         NaN    NaN   NaN    NaN  NaN   NaN
# 198         NaN    NaN   NaN    NaN  NaN   NaN
# 199         NaN    NaN   NaN    NaN  NaN   NaN
#
# [200 rows x 6 columns]

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   nombre      200 non-null    object
#  2   edad        200 non-null    int64
#  3   genero      200 non-null    object
#  4   pais        200 non-null    object
#  5   email       200 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 9.5+ KB

# %%
dataFrame = dataFrame.fillna({'nombre':'Sin nombre',
                                'edad':0,
                                'genero':'Indefinido',
                                'pais':'Ninguno',
                                'email':'example@example.com'
                                })

# %% [markdown]
# 16.3 Reemplazar usando la media, la mediana o la moda

# %%
import pandas as pd

df = pd.read_csv('data.csv')

# %%
# Media = el valor promedio (la suma de todos los valores dividida por el número de valores).
x = df["Calories"].mean()
# Mediana = el valor en el medio, después de haber ordenado todos los valores de forma ascendente.
y = df["Calories"].median()
# Moda = el valor que aparece con más frecuencia.
z = df["Calories"].mode()[0]

df["Calories"].fillna(x, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  169 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %% [markdown]
# 17 Limpieza de datos: formato incorrecto

# %% [markdown]
# 17.1 Convertir a un formato correcto

# %%
import pandas as pd

df = pd.read_csv('data.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# 17.2 Quitar filas

# %%
df.dropna(subset=['Date'], inplace = True)

# %% [markdown]
# Metodos pt2: strings

# %%
# startswith - endswith -contains (soporta LIKE)

# %%
import pandas as pd

data = pd.read_csv('src/users.csv')

data[ data['email'].str.startswith('a') ]
# Out:
#      Unnamed: 0                 nombre  edad  genero            pais  \
# 19           19      Ms Asta Jørgensen    72  female         Denmark
# 36           36        Mr Anthony Wong    42    male          Canada
# 43           43       Miss Anna Hansen    71  female         Denmark
# 53           53        Ms Aino Lassila    54  female         Finland
# 75           75    Ms Amparo Gutierrez    40  female           Spain
# 78           78         Miss عسل رضایی    66  female            Iran
# 86           86      Ms Ada Torbergsen    52  female          Norway
# 101         101      Mr Anton Johansen    56    male         Denmark
# 112         112  Mr Argemiro Gonçalves    69    male          Brazil
# 117         117       Mr Angel Herrera    66    male   United States
# 122         122       Mrs Allie Rhodes    65  female         Ireland
# 149         149          Ms Ana Castro    66  female           Spain
# 154         154          Ms آوین کریمی    59  female            Iran
# ...

# %%
import pandas as pd

data = pd.read_csv('src/users.csv')

data[ data['email'].str.endswith('.com') ]
# Out:
#      Unnamed: 0              nombre  edad  genero            pais  \
# 0             0    Mr Jerome Thomas    73    male   United States
# 1             1       Mr Gary Berry    70    male  United Kingdom
# 2             2     Mr Noham Dubois    40    male          France
# 3             3   Mrs Naja Johansen    63  female         Denmark
# 4             4  Mr Damien Marchand    61    male          France
# ..          ...                 ...   ...     ...             ...
# 195         195       Mr Raul Bravo    46    male           Spain
# 196         196   Miss Maeva Fortin    40  female          Canada
# 197         197   Mr Gabriel Berger    40    male          France
# 198         198  Mrs Ülkü Tanrıkulu    37  female          Turkey
# 199         199     Mr Raff Valkema    60    male     Netherlands
#
#                            email
# 0      jerome.thomas@example.com
# 1         gary.berry@example.com
# 2       noham.dubois@example.com
# 3      naja.johansen@example.com
# ...

# %%
import pandas as pd

data = pd.read_csv('src/users.csv')

data[ data['nombre'].str.contains('Gabriel') ]
# Out:
#      Unnamed: 0              nombre  edad genero           pais  \
# 26           26  Mr Gabriel Edwards    68   male  United States
# 197         197   Mr Gabriel Berger    40   male         France
#
#                            email
# 26   gabriel.edwards@example.com
# 197   gabriel.berger@example.com

# %% [markdown]
# Agrupamiento

# %%
# Mostrar en consola la cantidad de hombres y mujeres del dataset

import pandas as pd

data = pd.read_csv('src/users.csv')

data.groupby('genero')['genero'].count()
# Out:
# genero
# female    106
# male       94
# Name: genero, dtype: int64

# %%
# Mostrar el pais con mas mujeres

import pandas as pd

data = pd.read_csv('src/users.csv')

data[ data['genero'] == 'female' ].groupby('pais')['pais'].count().sort_values(ascending=False).head(1)
# Out:
# pais
# Denmark    12
# Name: pais, dtype: int64

# %% [markdown]
# Atributo: loc - iloc

# %%
import pandas as pd

username = ['user1','user2','user3','user4','user5']
email = ['user1@example.com','user2@example.com','user3@example.com','user4@example.com','user5@example.com']
age = [10,20,25,30,50]
status = [True,True,False,False,True]

dic = {'username': username,
       'email': email,
       'age':age,
       'status':status
       }

dataFrame = pd.DataFrame(dic)
dataFrame
# Out:
#   username              email  age  status
# 0    user1  user1@example.com   10    True
# 1    user2  user2@example.com   20    True
# 2    user3  user3@example.com   25   False
# 3    user4  user4@example.com   30   False
# 4    user5  user5@example.com   50    True

# %%
dataFrame.loc[0]
# Out:
# username                user1
# email       user1@example.com
# age                        10
# status                   True
# Name: 0, dtype: object

# %%
dataFrame.loc[0:2]
# Out:
#   username              email  age  status
# 0    user1  user1@example.com   10    True
# 1    user2  user2@example.com   20    True
# 2    user3  user3@example.com   25   False

# %%
dataFrame.loc[0:2,['username','email']]
# Out:
#   username              email
# 0    user1  user1@example.com
# 1    user2  user2@example.com
# 2    user3  user3@example.com

# %%
# int (iloc) - string (loc)

# %% [markdown]
# Condicionles

# %%
# Obtener el nombre de todos los usuarios del pais canada

# %%
import pandas as pd

data = pd.read_csv('src/users.csv', index_col=0)
data
# Out:
#                  nombre  edad  genero            pais  \
# 0      Mr Jerome Thomas    73    male   United States
# 1         Mr Gary Berry    70    male  United Kingdom
# 2       Mr Noham Dubois    40    male          France
# 3     Mrs Naja Johansen    63  female         Denmark
# 4    Mr Damien Marchand    61    male          France
# ..                  ...   ...     ...             ...
# 195       Mr Raul Bravo    46    male           Spain
# 196   Miss Maeva Fortin    40  female          Canada
# 197   Mr Gabriel Berger    40    male          France
# 198  Mrs Ülkü Tanrıkulu    37  female          Turkey
# 199     Mr Raff Valkema    60    male     Netherlands
#
#                            email
# 0      jerome.thomas@example.com
# 1         gary.berry@example.com
# 2       noham.dubois@example.com
# 3      naja.johansen@example.com
# 4    damien.marchand@example.com
# ..                           ...
# 195       raul.bravo@example.com
# 196     maeva.fortin@example.com
# ...

# %%
data['pais'] == 'Canada'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196     True
# 197    False
# 198    False
# 199    False
# Name: pais, Length: 200, dtype: bool

# %%
data[ (data['pais'] == 'Canada') ]
# Out:
#                   nombre  edad  genero    pais                         email
# 21         Mr Louis Ross    60    male  Canada        louis.ross@example.com
# 36       Mr Anthony Wong    42    male  Canada      anthony.wong@example.com
# 50        Mr Theo Miller    33    male  Canada       theo.miller@example.com
# 58    Miss Madison Ennis    49  female  Canada     madison.ennis@example.com
# 72        Ms Megan Brown    26  female  Canada       megan.brown@example.com
# 131       Mr Xavier Addy    30    male  Canada       xavier.addy@example.com
# 133   Miss Julia Ambrose    34  female  Canada     julia.ambrose@example.com
# 151        Mr Thomas Lam    42    male  Canada          thomas.lam@gmail.com
# 170        Mr Ryder Côté    25    male  Canada        ryder.cote@example.com
# 184   Mr Philip Bélanger    24    male  Canada   philip.belanger@example.com
# 193  Ms Delphine Ginnish    58  female  Canada  delphine.ginnish@example.com
# ...

# %%
data[ (data['pais'] == 'Canada')]['nombre']
# Out:
# 21           Mr Louis Ross
# 36         Mr Anthony Wong
# 50          Mr Theo Miller
# 58      Miss Madison Ennis
# 72          Ms Megan Brown
# 131         Mr Xavier Addy
# 133     Miss Julia Ambrose
# 151          Mr Thomas Lam
# 170          Mr Ryder Côté
# 184     Mr Philip Bélanger
# 193    Ms Delphine Ginnish
# 196      Miss Maeva Fortin
# Name: nombre, dtype: object

# %%
# Obtener el nombre y correo electronico de todos los usuarios con edad mayor a 50

# %%
data[ data['edad'] > 50 ][['nombre', 'email']]
# Out:
#                       nombre                           email
# 0           Mr Jerome Thomas       jerome.thomas@example.com
# 1              Mr Gary Berry          gary.berry@example.com
# 3          Mrs Naja Johansen       naja.johansen@example.com
# 4         Mr Damien Marchand     damien.marchand@example.com
# 5           Mr Harri Althoff       harri.althoff@example.com
# ..                       ...                             ...
# 189       Mr Carl Williamson     carl.williamson@example.com
# 190  Miss Margrietha Holster  margrietha.holster@example.com
# 193      Ms Delphine Ginnish    delphine.ginnish@example.com
# 194      Madame Rosa Lefevre        rosa.lefevre@example.com
# 199          Mr Raff Valkema        raff.valkema@example.com
#
# [97 rows x 2 columns]

# %%
# obtener el promedio de todos los usuarios de sexo femenino con una edad mayor a 30

data[ (data['genero'] == 'female') & (data['edad'] > 30)].mean()
# Out:
# /tmp/ipykernel_9150/1901677200.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data[ (data['genero'] == 'female') & (data['edad'] > 30)].mean()
# edad    52.068182
# dtype: float64

# %% [markdown]
# iLoc

# %%
data.iloc[199]
# Out:
# nombre             Mr Raff Valkema
# edad                            60
# genero                        male
# pais                   Netherlands
# email     raff.valkema@example.com
# Name: 199, dtype: object

# %%
data.iloc[0:5]
# Out:
#                nombre  edad  genero            pais  \
# 0    Mr Jerome Thomas    73    male   United States
# 1       Mr Gary Berry    70    male  United Kingdom
# 2     Mr Noham Dubois    40    male          France
# 3   Mrs Naja Johansen    63  female         Denmark
# 4  Mr Damien Marchand    61    male          France
#
#                          email
# 0    jerome.thomas@example.com
# 1       gary.berry@example.com
# 2     noham.dubois@example.com
# 3    naja.johansen@example.com
# 4  damien.marchand@example.com

# %%
data.iloc[:3,[0,2,4]]
# Out:
#              nombre genero                      email
# 0  Mr Jerome Thomas   male  jerome.thomas@example.com
# 1     Mr Gary Berry   male     gary.berry@example.com
# 2   Mr Noham Dubois   male   noham.dubois@example.com

# %% [markdown]
# 18 Graficar

# %%
data.plot()
# Out:
# <AxesSubplot:>
